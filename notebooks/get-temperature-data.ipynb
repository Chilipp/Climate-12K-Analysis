# %% [markdown]
# # Extraction of temperature data out of the Temperature12K LiPD files
#
# This notebook extracts the temperature data of all temperature series in the Temperature12K database and exports them in a tab-separated file. To get the latest version of the data, just click on *Cell* &rarr; *Run all*. When the notebook is finished (i.e. if you see a table [at the bottom](#final)), you can download the temperature data [here](../data/binned-temperature-data.tsv).
#
# This notebook downloads the database from http://lipdverse.org/globalHolocene/current_version, based on the version you specify in the `db_version` variable (see below). It has been developed by Philipp Sommer (philipp.sommer@unil.ch), please do not hesitate to get in touch if you run into any problems.
#
# **Things you might want to adapt:**
#
# - the database version string (`db_version`, see [here](#db_version))
# - the `binwidth` (by default 100, see [here](#binwidth)). We have to make averages over the time series in order to put everything together
# - the records you want to download (see [here](#filter))
# - the meta data for the temperature export (see [here](#meta-cols))

# %%
import pandas as pd
import lipd
import numpy as np
import contextlib
import os
import os.path as osp
from urllib import request
import zipfile

# %% [markdown]
# <a id=binwidth></a>We have to specify the bin widths in years. Each timeseries will be averaged into bins with this length in order to merge them all together.

# %%
binwidth = 100

# %% [markdown]
# <a id=db_version></a>Read in the LipD data from http://lipdverse.org/globalHolocene/current_version
#
# You should set the latest version here manually!

# %%
db_version = '0_30_1'

# %%
# %%time
if not osp.exists('../data'):
    os.makedirs('../data')
zipped = f'globalHolocene{db_version}.zip'
uri = f'http://lipdverse.org/globalHolocene/current_version/{zipped}'
target = osp.join('../data', zipped)
print('downloading ' + uri)
request.urlretrieve(uri, target)
with zipfile.ZipFile(target) as f:
    f.extractall('../data')
# Out:
# downloading http://lipdverse.org/globalHolocene/current_version/globalHolocene0_30_1.zip
# CPU times: user 289 ms, sys: 317 ms, total: 607 ms
# Wall time: 5.58 s

# %%
@contextlib.contextmanager
def remember_cwd():
    """Context manager to switch back to the current working directory

    Usage::

        with remember_cwd():
            os.chdir('test')
            print(os.getcwd())  # test
        print(os.getcwd())      # test/.."""
    curdir = os.getcwd()
    try:
        yield
    except:
        raise
    finally:
        os.chdir(curdir)

# %%
# %%time
with remember_cwd():
    os.chdir('../data/')
    data = lipd.readLipd('.')
# Out:
# Disclaimer: LiPD files may be updated and modified to adhere to standards
#
# Found: 943 LiPD file(s)
# reading: Hams.Bennett.1987.lpd
# reading: MV99-GC31.Barron.2012.lpd
# reading: EagleTarn.Rees.2010.lpd
# reading: Sonk11D.Lauterbach.2014.lpd
# reading: HjortSo.Wagner.2008.lpd
# reading: Alley.GISP2.2000.lpd
# reading: Victoria.Berke.2012.lpd
# reading: GeoB58044.Lamy.2003.lpd
# reading: Frozen.Rosenberg.2004.lpd
# reading: GeoB9307_3.lpd
# reading: Composit_MD012421,KR0206.lpd
# reading: FloatingIsland.Baker.1976.lpd
# reading: LakeSix.Liu.1990.lpd
# reading: ScreamingLynxLake.Clegg.2011.lpd
# reading: LonarLake.Prasad.2014.lpd
# reading: Malawi.Johnson.2016.lpd
# reading: WCA3B_GumboLimboFarTail.Willard.2001.lpd
# reading: Coghill.King.1986.lpd
# reading: Rogers.Marsicek.2013.lpd
# reading: LacduSommet.Hausmann.2011.lpd
# reading: BanksIsland74MS15.Gajewski.2000.lpd
# reading: Mohawk_Pond.Marsicek.2013.lpd
# reading: PetenItza.Curtis.1998.lpd
# reading: Dolgoe.Wolfe.2000.lpd
# reading: DevilsLake.Shuman.2016.lpd
# reading: GeoB9528-3.Collins.2013.lpd
# reading: MD95_2011.lpd
# reading: GeoB12615_4.lpd
# reading: LagunaChaplin.Pollen.Bolivia.lpd
# reading: M77_2_056_5.lpd
# Finished read: 943 records
# CPU times: user 1min 1s, sys: 5.6 s, total: 1min 7s
# Wall time: 1min 11s

# %% [markdown]
# Extract all the paleoData series from the data

# %%
# %%time
all_series = lipd.extractTs(data)
# Out:
# extracting paleoData...
# extracting: Hams.Bennett.1987
# extracting: MV99-GC31.Barron.2012
# extracting: EagleTarn.Rees.2010
# extracting: Sonk11D.Lauterbach.2014
# extracting: HjortSo.Wagner.2008
# extracting: Alley.GISP2.2000
# extracting: Victoria.Berke.2012
# extracting: GeoB58044.Lamy.2003
# extracting: Frozen.Rosenberg.2004
# extracting: GeoB9307_3
# extracting: Composit_MD012421,KR0206
# extracting: FloatingIsland.Baker.1976
# extracting: LakeSix.Liu.1990
# extracting: ScreamingLynxLake.Clegg.2011
# extracting: LonarLake.Prasad.2014
# extracting: Malawi.Johnson.2016
# extracting: WCA3B_GumboLimboFarTail.Willard.2001
# extracting: Coghill.King.1986
# extracting: Rogers.Marsicek.2013
# extracting: LacduSommet.Hausmann.2011
# extracting: BanksIsland74MS15.Gajewski.2000
# extracting: Mohawk_Pond.Marsicek.2013
# extracting: Sagistalsee.Pollen.Switzerland
# extracting: MD03_2611
# extracting: ODP1084B
# extracting: GiK18515_3
# extracting: DolgoeOzero.Pollen.Russia
# extracting: MD06_3075
# extracting: gunnarsfjorden.Allen.2007
# extracting: MundayCreek.Peteet.1986
# extracting: Buckeye.Hardt.2010
# extracting: Saarikko.Heikkil.2010
# extracting: sjuuodjijaure.Rosen.2001
# extracting: Lochnagar.Dalton.2005
# extracting: lapland.Helama.2010
# extracting: LakeSixteen.Futyma.1986
# extracting: Stazersee.Heiri.2015
# extracting: LakeBolshieToroki.Pollen.Russia
# extracting: GIK17049_6
# extracting: Wonderkrater.Scott.2016
# extracting: NevadoHuascaran.Thompson.1995
# extracting: HumberPond3.McAndrews.1989
# extracting: Jansvetnet.Birks.2012
# extracting: LakePupuke.Pollen.NewZealand
# extracting: PechoraLake.Andren.2015
# extracting: Bosten.Chen.2008
# extracting: TN062-0550.Barron.2018
# extracting: Varddoaijavri.Luoto.2014
# extracting: TalkinTarn.Langdon.2004
# extracting: Nattmalsvatn.Janbu.2011
# extracting: Issyk.Chen.2008
# extracting: GeoB4905.Weldeab.2005
# extracting: BattleGround.Whitlock.1985
# extracting: JR244_GC528
# extracting: 117_723A
# extracting: PortageLake.McAndrews.NA
# extracting: Lynn.Nichols.1967
# extracting: dravladalsvatn.Bakke.2005
# extracting: Burden.Webb.1986
# extracting: UnitLake.Camill.2012
# extracting: SP10WINZ.Williams.2010
# extracting: V1927
# extracting: PC56_grayscale.Hughen.2000
# extracting: GrandRapids.Ritchie.1975
# extracting: Alzasca.Wirth.2013
# extracting: MD03_2607
# extracting: Duck.Winkler.1985
# extracting: Llet-Ti.Pollen.Russia
# extracting: DonggeCave_b
# extracting: CaribouHill.Lamb.1985
# extracting: Takahula.Clegg.2010
# extracting: PlateauRemote.MosleyThompson.1996
# extracting: GeoB71392.Kaiser.2008
# extracting: Ennadai_1972Site.Nichols.1975
# extracting: Sofular.Fleitmann.2009
# extracting: JohnKlondike.Matthews.1980
# extracting: LagoVerdarolo.Samartin.2011
# extracting: Iglutalik.Davis.NA
# extracting: KF16
# extracting: SP02.Adams.2010
# extracting: MD01-2446.Salguero.2014
# extracting: ParkPond3.Lynch.1998
# extracting: Lyadhej-To.Andreev.2005
# extracting: ARC4.Belt.2010
# extracting: ODP967D.Emeis.2000
# extracting: MD01-2412.Harada.2006
# extracting: Ledro.Wirth.2013
# extracting: PS2641.Muller.2012
# extracting: GravelRidge.Lamb.1985
# extracting: LakeLR1.Gajewski.1993
# extracting: Hinterburg.Wirth.2013
# extracting: PointEscuminac.Warner.1991
# extracting: Hirvijaervi.Luoto.2010
# extracting: GeoB10043_3
# extracting: Hovsgol.Chen.2008
# extracting: ODP967.Larrasoana.2008
# extracting: Redstone.Brubaker.1985
# extracting: Kennys.Macpherson.1983
# extracting: Vostok_Antarctica
# extracting: BogD.McAndrews.1966
# extracting: ParkPond2.Lynch.1998
# extracting: BiglandTarn.Barber.2013
# extracting: Medicine.Radle.1992
# extracting: trehorningen.Antonsson.2007
# extracting: Chatsworth.King.1981
# extracting: HealLake.Brown.2006
# extracting: Midden.Cluster9.2019
# extracting: KNR140_51GGC
# extracting: Midden.Cluster8.2019
# extracting: GeoB58044.Lamy.2005
# extracting: H214
# extracting: Hamundarstadhahals.Caseldine.2006
# extracting: ClarksJunction.Pollen.NewZealand
# extracting: ARC3.Belt.2010
# extracting: AjaxBog.Pollen.NewZealand
# extracting: HiddenLake.Potito.2006
# extracting: DomeC.Stenni.2001
# extracting: E_Lake.Ritchie.1976
# extracting: LacFaribault.Larouche.1981
# extracting: OliverPond_1770.McAndrews.1990
# extracting: Sud_duLac_duNoyer.Larouche.1977
# extracting: M25_4_KL11
# extracting: Deltasoe.Axford.2019
# extracting: raigastvere.Seppa.2004
# extracting: Asia-LakeHuguangMaar
# extracting: BotuveraCave
# extracting: MeerfelderMaar.Pollen-Germany-MeerfelderMaar.Kuehl
# extracting: SihailongwanMaarLake.Stebich.2015
# extracting: Koucha.Pollen.China
# extracting: Nina.Liu.1990
# extracting: Marion_BC.Mathewes.1973
# extracting: KeystoneIronbog.Fall.1985
# extracting: LacPetel.King.1986
# extracting: MD06_3067
# extracting: NevadaPrecip.Hughes.1996
# extracting: GRIP.Vinther.2006
# extracting: Jewell.Baker.1986
# extracting: Garlate.Wirth.2013
# extracting: njakajaure.Bigler.1998
# extracting: Pickerel.Shuman.2016
# extracting: dalene.Eide.2009
# extracting: ArolikLake.Hu.2003
# extracting: tornetrask.Grudd.2002
# extracting: Gerzensee.Cladocera.Switzerland
# extracting: Ladd.Shane.1993
# extracting: BI2.Gajewski.1992
# extracting: Brandreth.Overpeck.1985
# extracting: HeihaiLake.Chang.2017
# extracting: Pallcacocha.Moy.2002
# extracting: SS16.Perren.2012
# extracting: Marion.Mathewes.1973
# extracting: O2kLR-Tagusmudpatc.Abrantes.2005
# extracting: GeoB58044.Lamy.2004
# extracting: grostjorn.Eide.2009
# extracting: GeoB5844_2
# extracting: DHP174.Porter.2019
# extracting: Qixing.Cai.2001
# extracting: Hvitarvatn.Larsen.2013
# extracting: LacGras.King.1986
# extracting: LakeHintererSchwendisee.Wirth.2013
# extracting: Minucua.Goman.2018
# extracting: HawkeHillsKettle.Macpherson.1982
# extracting: LakeWestOkoboji.Van.1979
# extracting: GeoB58044.Lamy.2006
# extracting: Chatsworth.Shuman.2016
# extracting: Toskaljavri.Seppa.2002
# extracting: jarburvatnet.Nesje.2001
# extracting: Harrie.King.1986
# extracting: SanbaoSB43.Dong.2010
# extracting: MD032707.Weldeab.2007
# extracting: agassiz.Vinther.2009
# extracting: Heihai.Ramisch.2016
# extracting: BanksIsland74MS11.Gajewski.2000
# extracting: RedmountainLake.Chase.2008
# extracting: BearBog.McAndrews.1992
# extracting: Midden.Cluster3.2019
# extracting: Midden.Cluster2.2019
# extracting: M40-4-SL78.Emeis.2003
# extracting: braya_so.Dandrea.2011
# extracting: Ammersee.Czymzik.2012
# extracting: MSM5_512
# extracting: JamesRossIsland.Mulvaney.2012
# extracting: LakeNalengcuo.Pollen.China
# extracting: Big.Cumming.2002
# extracting: ODP1019.Barron.2003
# extracting: ColdWater.Denniston.1999
# extracting: MD952042.Bard.2002
# extracting: JM98-1.Husum.2004
# extracting: Hams.Shuman.2016
# extracting: Logan.Fisher.2008
# extracting: GeoB9508_5
# extracting: OwensLake.Benson.2002
# extracting: Emerald.Shuman.2014
# extracting: PortageBog.Anderson.1980
# extracting: vuoskkujavri.Bigler.2002
# extracting: PorquiPond.McAndrews.NA
# extracting: dalmutladdo.Bjune.2004
# extracting: PSh-5157.Risebrobakken.2011
# extracting: Buckeye.Springer.2008
# extracting: CC04
# extracting: KZAI_01
# extracting: Elfstadalsvatn.Langdon.2008
# extracting: M_Lake.Ritchie.1977
# extracting: sfl4-1.Willemse.1999
# extracting: MD012378.Xu.2008
# extracting: Seelisberg.Wirth.2013
# extracting: ThunderLake.Chase.2008
# extracting: PolevaCave.Constantin.2007
# extracting: Kenosee.Porter.1992
# extracting: SSDP102
# extracting: GRIP_accumulation.Vinther.2006
# extracting: LakeEC1.Gajewski.1993
# extracting: PL0739PC.Lea.2003
# extracting: NBJ2015iso.Wong.2015
# extracting: PSh-5159N.Risebrobakken.2011
# extracting: AwengCo.Li.2017
# extracting: PinkPanther.Asmerom.2007
# extracting: SU81_18
# extracting: LakeEC2.Gajewski.1991
# extracting: DajiuhuPeatland.Huang.2013
# extracting: MSM055_723-2.Werner.2015
# extracting: spaime.Hammarlund.2004
# extracting: PathLake.Neil.2014
# extracting: Ennadai.Nichols.1967
# extracting: Corser.Nichols.2014
# extracting: SS49.Perren.2012
# extracting: Kyutyunda.Pollen.Russia
# extracting: SprucePond.Shuman.2016
# extracting: Minnetonka.Lundeen.2013
# extracting: 161_976
# extracting: JiuxianCave.Cai.2010
# extracting: MSM05_5_723_2
# extracting: MD01_2378
# extracting: waskey.Levy.2004
# extracting: TN062-0550.Addison.2018
# extracting: LacMartyne.McAndrews.NA
# extracting: fauske.Linge.2009
# extracting: KaiteCobreMayor.Martin-Chivelet.2011
# extracting: Peggy.McAndrews.NA
# extracting: GeoB6211_2
# extracting: MooseLake.Clegg.2010
# extracting: penny.Fisher.1998
# extracting: DonggeCave.Wang.2005
# extracting: MD03_2699
# extracting: YakYakumo.Leipe.2013
# extracting: LakeLyadhej-To.Andreev.2005
# extracting: igaliku.Massa.2012
# extracting: LochantSuidhe.Edwards.2007
# extracting: Khoe.Leipe.2015
# extracting: igelsjon..2003
# extracting: GeoB12605_3
# extracting: LacColin.Mott.1977
# extracting: Decoy.Szeicz.1991
# extracting: PC_01
# extracting: SouthRhodyBog.Booth.2012
# extracting: POS362_2_33
# extracting: Little.Whitlock.1995
# extracting: Yanahaizi.Chen.2003
# extracting: Egelsee.Larocque.2010
# extracting: Baldegg.Wirth.2013
# extracting: Camp11.Brubaker.1975
# extracting: MD99-2322.Jennings.2011
# extracting: Duck_Pond.Marsicek.2013
# extracting: soylegrotta.Lauritzen.1999
# extracting: OregonCaves.Ersek.2012
# extracting: GeoB10235.Kim.2002
# extracting: PerchLake_Manitoba.Ritchie.NA
# extracting: LV29_114_3
# extracting: MD84_527
# extracting: GeoB9508-5.Collins.2013
# extracting: MD02_2575.Ziegler.2008
# extracting: ODP1098B
# extracting: Moraine.Hansen.1985
# extracting: MD99-2284.Risebrobakken.2009
# extracting: Chaohu.Pollen.China
# extracting: KirmanLake.MacDonald.2016
# extracting: MoonLake.Shuman.2016
# extracting: hallet.McKay.2009
# extracting: LacBrule.Pollen.Canada
# extracting: LakeStowell.Lemmen&Lacourse.2018
# extracting: klotjarnen.Seppa.2009
# extracting: HodellMiragoane1991
# extracting: BS7938
# extracting: DSDP480.Barron.2004
# extracting: JR51-GC35.Bendle.2007
# extracting: SaintCalixte.Larouche.NA
# extracting: MD982181
# extracting: LakeLR3.Gajewski.1992
# extracting: vikjordvatnet.Balascio.2012
# extracting: WCA3B_GumboLimboMarsh.Willard.2001
# extracting: GEOFAR_KF16_MgCa.Repschlager.2016
# extracting: EagleLake.Lamb.1980
# extracting: RAPID-12.Thournally.2009
# extracting: Lake31.Eisner.1995
# extracting: Midden.Cluster4.2019
# extracting: BanksIsland74MS12.Gajewski.2000
# extracting: Midden.Cluster5.2019
# extracting: MD01_2390
# extracting: JM96-1207.Solignac.2013
# extracting: Mohawk.Webb.1986
# extracting: MD952015
# extracting: SchwarzseeobSoelden.Ilyashuk.2011
# extracting: KR02.Pollen.Canada
# extracting: Holtjaernen.Pollen.Sweden
# extracting: VestreOEykjamyrtjoern.Pollen.Sweden
# extracting: myrvatn.Seppa.2009
# extracting: trettetjorn.Bjune.2005
# extracting: Reidel.Almquist.1992
# extracting: ennadai.Bender.1967
# extracting: LouisePond.Mathewes.1994
# extracting: GeoB10042_1
# extracting: SoreqCave
# extracting: Abalone.Cole.1994
# extracting: LakeoftheWoods.Palmer.2002
# extracting: Ramsay.Mott.1978
# extracting: MeliLake.Anderson.2001
# extracting: BerryPond.Shuman.2004
# extracting: svanavatnet.Bjune.2008
# extracting: MSM055_712-2.Werner.2015
# extracting: isbenttjonn.Seppa.2009
# extracting: oykjamyrtjorn.Bjune.2005
# extracting: TanaLake
# extracting: VestreOykjamytjorn.Velle.2005
# extracting: MD032601.Crosta.2007
# extracting: Wolverine.Mann.2002
# extracting: Nutt.Shuman.2016
# extracting: Cadagno.Niemann.2012
# extracting: DomeF.Kawamura.2007
# extracting: Holebudalen.Seppa.2009
# extracting: Hongyuan.Yu.2006
# extracting: GreatBasin.Salzer.2013
# extracting: TaquitzMeadow.Pollen.USA
# extracting: Aus-MorosMurrayCanyon
# extracting: B997-321.Smith.2005
# extracting: LakePupuke.VandenBos.2018
# extracting: ElGygytgynCrater.Schwamborn.2006
# extracting: Irvin.Cushing.1982
# extracting: MorrisPond.Morris.2013
# extracting: High.Fuller.1997
# extracting: GeoB9526-5.Collins.2013
# extracting: LakeBN7.Gajewski.1991
# extracting: PotrokAike.Massaferro.2013
# extracting: ODP1751078C
# extracting: Lofty.Lichti.1970
# extracting: Agassiz.Lecavalier.2017
# extracting: Gucheng.Pollen.China
# extracting: Indian.Bjorck.1985
# extracting: Dune.Finney.2012
# extracting: CoppermineSaddleback.Nichols.1975
# extracting: Svartvatnet.Luoto.2018
# extracting: M75_3_137_3
# extracting: Lions.Sabatier.2012
# extracting: Neor.Sharifi.2015
# extracting: NorthCraterLake.Palmer.2002
# extracting: kortlanda..2008
# extracting: BloodPond.Marsicek.2013T
# extracting: ColdAirCave
# extracting: s53s52.Tillman.2010
# extracting: farewell.Hu.1998
# extracting: nautajarvi.Ojala.2009
# extracting: MD99-2317.Jennings.2011
# extracting: SN-6.STiwari.2015
# extracting: Rystad.Vorren.2012
# extracting: GeoB100384.Mohtadi.2010
# extracting: XingyunLake.Wu.2018
# extracting: JPC76.Friddell.2002
# extracting: MD022529.Leduc.2007
# extracting: GYXO.Self.2015
# extracting: Porphyry.Brown.2002
# extracting: SanJuanRiverDischarge.Brown.2015
# extracting: TigrePerdido.vanBreukelen.2008
# extracting: hudson.Clegg.2011
# extracting: Mount_Honey
# extracting: tibetanus.Hammarlund.2002
# extracting: FinseStasjonsdam.Velle.2005
# extracting: Devils.Maher.1982
# extracting: Kharinei.Pollen.Russia
# extracting: 893A.Kennet.2007
# extracting: LeadingTickles.Macpherson.1985
# extracting: SouthernCalifornia.OhlweinWahl.2012
# extracting: DA05.Lloyd.2007
# extracting: QunfCave.Fleitmann.2007
# extracting: starvatn.Andresen.2006
# extracting: Aus-MarxUpperSnowy
# extracting: V2130
# extracting: GeoB10069-3.Gibbons.2014
# extracting: FoyLake.Stone.2008
# extracting: Crates.Liu.NA
# extracting: ParkPond1.Lynch.1998
# extracting: PeatlandKlukva.Pollen.Russia
# extracting: Compass.Macpherson.1986
# extracting: Svartkalstjarn..2010
# extracting: Mansell.Shuman.2016
# extracting: AralSea.Chen.2008
# extracting: GeoB65181.Schefu.2005
# extracting: MD07-3104.Pollen.Chile
# extracting: TangledUpLake.Anderson.2001
# extracting: kjennsvatn.Bakke.2010
# extracting: D13822
# extracting: CarletonLake(informalname).Upiter.2014
# extracting: GrahamLake.Shuman.2016
# extracting: Tourbiere_deLanoraieJoseph.Comtois.1982
# extracting: HM03_133_25
# extracting: ODP-984.Came.2007
# extracting: BOFS5K
# extracting: kusawa.Chakraborty.2010
# extracting: Deep.Marsicek.2013
# extracting: Vuoksjavratje.Berntsson.2014
# extracting: ODP1671017E
# extracting: Atocas.Gauthier.1981
# extracting: GeoB7702-3.Castaneda.2016
# extracting: SIPLEMelt.Das.2008
# extracting: ratasjoen.Velle.2005
# extracting: ClelandLake.Steinman.2016
# extracting: Maplehurst.Mott.1978
# extracting: BisonLake.Anderson.2011
# extracting: laihalampi.Heikkila.2003
# extracting: kinnshaugen.Seppa.2009
# extracting: Davis.Newby.2014
# extracting: Ferndale.Albert.1981
# extracting: Tourbiere_deLanorieHenri.Comtois.1982
# extracting: Windy.Chase.2008
# extracting: KY07_04_01.Kubota.2010
# extracting: JR01.Fortin&Gajewski.2017
# extracting: MSM343300
# extracting: BighornBasin.Shuman.2012
# extracting: JinchueanBog.Yu.2013
# extracting: Longwoods.Pollen.NewZealand
# extracting: LoonPond.Jacobson.Ja
# extracting: GeoB7920-2.Collins.2013
# extracting: Qipisarqo.Wooller.2004
# extracting: HAP0212.vanderBilt.2016
# extracting: HU90.deVernal.2013
# extracting: BoothIrwinSmith2012
# extracting: ODP658C.deMenocal.1997
# extracting: MD012390.Steinke.2008
# extracting: TaulMuced.Diaconu.2017
# extracting: M77_2_059_1
# extracting: jake.Kerwin.2005
# extracting: Crowsnest.Anderson.NA
# extracting: GIK18287_3
# extracting: M39008.Cacho.2001
# extracting: Sigrid.Nazarova.2017
# extracting: N14..2004
# extracting: Hershop.Larson.1972
# extracting: LakeNikolay.Pollen.Russia
# extracting: Spannagel.Fohlmeister.2012
# extracting: devon.Fisher.1983
# extracting: Gould.Jacobson.1992
# extracting: M35003_4
# extracting: TTR-12_293G.Rodrigo-Gamiz.2014
# extracting: HumberPond5.McAndrews.1989
# extracting: Fiskebolvatnet.Balascio.2012
# extracting: MD02_2529
# extracting: ODP658C_UK37.Zhao.1995
# extracting: NorthPond.Whitehead.1978
# extracting: Kotokel.Tarasov.2009
# extracting: GIK23258.Sarnthein.2003
# extracting: Clearwater.Mott.1973
# extracting: LacLeonard.Labelle.1984
# extracting: Beaverhouse.Ritchie.1976
# extracting: LO09.Berner.2008
# extracting: StewartsDark.Peters.1984
# extracting: Hanging.Cwynar.1982
# extracting: AlanenLaanijarvi.Heinrichs.2005
# extracting: P178-15P.Tierney.2015
# extracting: LacMeleze.MacDonald.1987
# extracting: Zabieninec.Plociennik.2011
# extracting: BloodPond.Marsicek.2013
# extracting: Elsinore.Kirby.2010
# extracting: big_round.Thomas.2010
# extracting: Hidden.Shuman.2009
# extracting: PassLake.McAndrews.1986
# extracting: KR02.Peros.2008
# extracting: WA01.Rainville.2013
# extracting: Olive-backedLake.Self.2015
# extracting: MD99-2264.Olafsdottir.2010
# extracting: RiviereFeuilles1.Larouche.1981
# extracting: MSM05-712.Muller.2013
# extracting: BoomerangLake.Brown.2006
# extracting: tsuolbmajavri.Korhola.2009
# extracting: Hinterburgsee.Heiri.2003
# extracting: Bjornfjell.Brooks.2006
# extracting: renland.Vinther.2009
# extracting: BerryPondWest1979
# extracting: Asia-LianhuaCave
# extracting: BegbieLake.Brown.2019
# extracting: WCA3B_GumboLimboWetHead.Willard.2001
# extracting: Hani.Zheng.2017
# extracting: MD97_2151
# extracting: Gass.Webb.1983
# extracting: DavisLake.Whitlock.1981
# extracting: ME005A43JC
# extracting: CuevadeAsiul.Smith.2016
# extracting: rainbow.Clegg.2011
# extracting: V12-107.Schmidt.2016
# extracting: k2.Fallu.2005
# extracting: Gammelheimvatnet.Seppa.2009
# extracting: PlatypusTarn.Rees.2010
# extracting: Castor.Nelson.2011
# extracting: LakeLB1.Gajewski.1993
# extracting: CottonwoodLake.Grimm.1987
# extracting: DANA12_11_2_GC01
# extracting: Midden.Cluster1.2019
# extracting: LacAurelie.Bajolle.2018
# extracting: EDML.Stenni.2009
# extracting: CottonwoodPassPond.Fall.1997
# extracting: PP10-07.Mary.2016
# extracting: SouthAfricanSummerRainfallZone.Climate-12k-Site-Data-Entry-Form-v3.SASRZ
# extracting: ranger.Brubaker.1983
# extracting: Deep.Shuman.2016
# extracting: PixieLake.Brown.2006
# extracting: MD95-2040.Salguero.2014
# extracting: Jack.Liu.1985
# extracting: Gilltjarnen.Antonsson.2006
# extracting: LittleWindy.Minckley.2012
# extracting: Balikun.Chen.2008
# extracting: HU91.Levac.2013
# extracting: OCE326GGC26
# extracting: Nerfloen.Vasskog.2012
# extracting: StaroselskyMoch.Pollen.Russia
# extracting: BS7933
# extracting: McMaster.Moser.1990
# extracting: Tumbulovaty.Kultti.2004
# extracting: Berry.Whitehead.1979
# extracting: Gushantun.Zheng.2018
# extracting: TaylorDome_dD
# extracting: Bastien.Bennett.1987
# extracting: MD99-2256.Olafsdottir.2010
# extracting: OCE326GGC30
# extracting: Flarken.Seppa.2005
# extracting: South_Island
# extracting: Cummins.McAndrews.1984
# extracting: LakeXimencuo.Pollen.China
# extracting: lake850.Shemesh.2001
# extracting: Kharinei.Jones.2011
# extracting: LakeCF8.Axford.2011
# extracting: Kurupa.Boldt.2015
# extracting: LawDome.Dahl-Jensen.1999
# extracting: HulunLake.Wen.2009
# extracting: HomesteadScarp.McGlone.2010
# extracting: CangoCave.Climate-12k-Site-Data-Entry-Form-v3.Cango
# extracting: DevonIslandGlacier.McAndrews.1984
# extracting: SaintGabriel.Larouche.1977
# extracting: Edward.Russell.2003
# extracting: Cadagno.Wirth.2013
# extracting: NP04KH3KH4.Tierney.2008
# extracting: Hudson.Bailey.1972
# extracting: LagoMoreno.Pollen.Argentina
# extracting: LostLake_MT.Whitlock.1989
# extracting: ODP1019D
# extracting: LittleBass.Swain.NA
# extracting: arapisto.Sarmaja-Korjonen.2007
# extracting: DonggeCave.Dyoski.2005
# extracting: Hypkana.Hajkova.2016
# extracting: LakeKupal'noe.Ilyashuk.2013
# extracting: MSM05-723..2012
# extracting: Pingwang.Pollen.China
# extracting: SO139-74KL.Luckge.2008
# extracting: LakeVan.Chen.2008
# extracting: 165_1002C
# extracting: CH0798GGC19
# extracting: MD02-2515.Bhattacharya.2018
# extracting: LowerBearLake.Kirby.2012
# extracting: BeaverLake.Schmieder.2011
# extracting: EnosLake.Brown.2006
# extracting: Hinterburgsee.Heiri.2015
# extracting: Mendota.Winkler.1986
# extracting: Moon.Grimm.1996
# extracting: Tigalmamine.Climate-12k-Site-Data-Entry-Form-v3.Tigalmamine
# extracting: gloppsjon.Seppa.2009
# extracting: GeoB7622-2.Lamy.2006
# extracting: MD982176
# extracting: Ghirla.Wirth.2016
# extracting: LacLouis.Vincent.1973
# extracting: Grenadier.McAndrews.1988
# extracting: NewLong.Newby.2014
# extracting: LimeLake.Steinman.2016
# extracting: HomesteadScarp,CampbellIsland.Pollen.NewZealand
# extracting: Malawi.Powers.2005
# extracting: LongLake.Kay.1979
# extracting: StellaLake.Reinemann.2009
# extracting: SanLuisLake.Yuan.2013
# extracting: JM01-1199.Hald.2007
# extracting: LakeGB2.Gajewski.1993
# extracting: Pickerel_SD.Watts.1968
# extracting: tiavatnet.Seppa.2009
# extracting: 18287-3.Kienast.2001
# extracting: Kirchner.Wright.1963
# extracting: nikolay.Andreev.2004
# extracting: Troll28-03.Klitgard-Kristensen.2001
# extracting: lonespruce.Kaufman.2012
# extracting: 74KL_UK37.Huguet.2006
# extracting: Qipisarqo.Frechette.2009
# extracting: AlfonsoBasin.StainesUrias.2015
# extracting: 2005-804.Ledu.2013
# extracting: GeoB7625-2.Lamy.2006
# extracting: YellowLake.Anderson.2012
# extracting: Graham.Fuller.1997
# extracting: MilandreCav.Affolter.2019
# extracting: iglutalik.Davis.1980
# extracting: P1003.Sejrup.2011
# extracting: 2004_804_009_PC
# extracting: Aus-WilkinsKeilambeteGnotuk
# extracting: candelabra.Cwynar.1995
# extracting: upper_fly.Bunbury.2009
# extracting: MD972120
# extracting: CariacoBasin.Haug.2001
# extracting: trout.Irvine.2012
# extracting: EaglenestLake.Vance.1986
# extracting: MD95-2011.Berner.2010
# extracting: CaribouLake.Rolland.2008
# extracting: Laihalampi.Pollen.Sweden
# extracting: austerkjosen.Seppa.2009
# extracting: RhamnusLake.Brown.2006
# extracting: Jeita.Cheng.2015
# extracting: NoBottom.Dunwiddie.1990
# extracting: M39_008
# extracting: SO90_56KA
# extracting: MD99-2227.deVernal.2013
# extracting: BJ8_70GGC
# extracting: Khatanga-12Lake.Syrykh.2017
# extracting: TorontoLake.Wolfe.1996
# extracting: RC12-10.Poore.2003
# extracting: MV99-GC41.Marchitto. 2010
# extracting: MD79257
# extracting: Tanganyika.Tierney.2008
# extracting: MD972121
# extracting: CuevaDiablo.Bernal.2011
# extracting: Delorme1.Bouchard.1982
# extracting: BJ8_13GGC
# extracting: SpringValleyCave.Denniston.1999
# extracting: M25and4KL11.Emeis.2003
# extracting: Hinterburgsee.Heiri.2004
# extracting: njulla.Bigler.2003
# extracting: Ghirla.Wirth.2013
# extracting: MD98_2188
# extracting: UpperBigCreek.Shuman.2015
# extracting: No_Bottom_Pond.Marsicek.2013
# extracting: HU84.deVernal.2013
# extracting: Ammersee.vonGrafenstein.1996
# extracting: PM9462_4
# extracting: LakeBerkut.Ilyashuk.2005
# extracting: PC2.Seki.2004
# extracting: NIOP905_TEX86
# extracting: Sokli.Shala.2017
# extracting: ClearLake_Iowa.Baker.1992
# extracting: MD07-3088.Pollen.Chile
# extracting: Njulla.Larocque&Hall.2004
# extracting: Posy.Shafer.1989
# extracting: MysteryCave..2004
# extracting: EDC.Jouzel.2007
# extracting: SO189-39KL.Mohtadi.2014
# extracting: Nutt.Bennett.1987
# extracting: Chichancanab.Hodell.1995
# extracting: chuna.Jones.2005
# extracting: UpperPintoFen.Yu.2003
# extracting: BorderBeacon.Lamb.1985
# extracting: Pella.Climate-12k-Site-Data-Entry-Form-v3.Pella
# extracting: MD99-2269.Justwan.2008
# extracting: PerchLake_ON.Terasmae.1975
# extracting: MD01-2416.Sarnthien.2004
# extracting: ruila.Seppa.2004
# extracting: Haukdalsvatn.Larsen.2013
# extracting: LehmanCaves.Steponaitis.2015
# extracting: GeoB12610_2
# extracting: MD982165
# extracting: KT05_7_PC_02
# extracting: LakeAspvatnet_ELA.Bakke.2005
# extracting: O2kLR-CapeGhirNWAf.Kim.2006
# extracting: MD02-2517.Bhattacharya.2018
# extracting: M350034.Rhlemann
# extracting: Klotjaernen.Pollen.Sweden
# extracting: Sysy-Kyuele.Biskaborn.2012
# extracting: GeoB65181_MBT.Weijers.2007
# extracting: Heshang.Wang.2018
# extracting: CascadeFen.Maher.1963
# extracting: GIK17940_2
# extracting: Billys.Jacobson.1975
# extracting: LagoGeminiInferiore.Samartin.2011
# extracting: TauldintreBrazi.Toth.2015
# extracting: LaPAS_KF02
# extracting: Carp.Whitlock.1985
# extracting: IOW225514.Elmis.2003
# extracting: LakeCH2.Garralla.1992
# extracting: TourbiereDeLanoraieSTJEAN.Comtois.1982
# extracting: LakeChalla.Climate-12k-Site-Data-Entry-Form-v3.Challa
# extracting: PTHE.Self.2015
# extracting: DomeC.Jouzel.2007
# extracting: KR02.Fortin&Gajewski.2010
# extracting: flower_valley..2013
# extracting: Chron.Iceland.2013
# extracting: LakeAspvatnet_precip.Bakke.2005
# extracting: BCTempComp.Gavin.2013
# extracting: BasadelaMoraLake.Tarrats.2018
# extracting: MD94-103.Sicre.2005
# extracting: ThreePinesBog.McAndrews.1990
# extracting: AMP112.vanderBilt.2016
# extracting: flotatjonn.Seppa.2009
# extracting: Holzmaar.Luke.
# extracting: MD02-2553.Poore.2009
# extracting: SumxiCo.Leipe.2014
# extracting: Nichols.Corser.2014
# extracting: BC01.Peros.2010
# extracting: SilverLake.Kirby.2015
# extracting: HLY0501.deVernal.2013
# extracting: Core_63KA
# extracting: MD982170
# extracting: GGC19.Farmer.2011
# extracting: SV_04
# extracting: MonheganIslandMeadow.Bostwick.1978
# extracting: GISP2.Alley.2000
# extracting: MicaLake.Schiff.2009
# extracting: BrayaSo.vonGunten.2012
# extracting: LostLake_MI.Brubaker.1975
# extracting: Jones.Shapley.2009
# extracting: Steel.Shuman.2016
# extracting: GeoB59012.Kim.2004
# extracting: ForestPond1.Lynch.1998
# extracting: MD97-2151.Yamamoto.2013
# extracting: Whatever.Wolfe.1996
# extracting: Topptjonna.Paus.2011
# extracting: TR163_22
# extracting: MB01.Pollen.Canada
# extracting: Mo05LakeMondsee.Swierczynski.2013
# extracting: Hulun.Chen.2008
# extracting: GeoB3129.Weldeab.2006
# extracting: P1B3.deVernal.2005
# extracting: ClearLake_Indiana.Bailey.1972
# extracting: Jenny.Larson.2016
# extracting: century.Vinther.2009
# extracting: LacNoir.Pollen.Canada
# extracting: Kollioksak.Anderson.NA
# extracting: yarnyshnoe.Seppa.2008
# extracting: Glattalp.Wirth.2013
# extracting: Telmen.Chen.2008
# extracting: LoughMeenachrinna,CountyDonegal.Taylor.2018
# extracting: quartz.Wooller.2012
# extracting: Gerzensee.Pollen.Switzerland
# extracting: SK168_GC_1
# extracting: KinderlinskayaCave.Baker.2017
# extracting: Colo.Baker.1990
# extracting: LacMarcotte.Labelle.1981
# extracting: SS8.Anderson.2012
# extracting: Furnival.McAndrews.NA
# extracting: NIOP905_UK37
# extracting: SecretLake.Lasher.2017
# extracting: Minakokosa.Anderson.NA
# extracting: Mawmluh.Berkelhammer.2012
# extracting: BeefPasture.Petersen.1985
# extracting: brurskardstjorni.Velle.2005
# extracting: haugtjern.Eide.2009
# extracting: PolandSpring.Jacobson.Ja
# extracting: KP2.Seppa.2009
# extracting: Myrtle.Janssen.1968
# extracting: Jellybean.Anderson.2005
# extracting: meleze.MacDonald.1983
# extracting: WAISBubble.Fegyveresi.2016
# extracting: SL06.Pollen.Canada
# extracting: SK237-GC04.Saraswat.2013
# extracting: AD9117.Guinta.2001
# extracting: Little_Pond_Royalston.Marsicek.2013
# extracting: Delorme2.Bouchard.1982
# extracting: LagunaDeJuanacatlan.Jones.2015
# extracting: SacredLake
# extracting: Caribou.Labelle.1992
# extracting: Kilimanjaro.Thompson.2002
# extracting: Medvedevskoe.Nazarova.2018
# extracting: Core17940
# extracting: Mjauvotn.Olsen.2010
# extracting: MD99_2304
# extracting: lily.Cwynar.1990
# extracting: NH-8P.Bhattacharya.2018
# extracting: Sharkey.Shuman.2016
# extracting: MD95_2002
# extracting: Iffig.Wirth.2013
# extracting: TaylorDome_d18O
# extracting: Saint-JeanIle_dOrleans.Larouche.1971
# extracting: SO136GC11.Barrows.2007
# extracting: Ew0408-85JC.Praetorius.2015
# extracting: PL-96.Voronina.2013
# extracting: MD05_2904
# extracting: LakeHopeSimpson.Hansen.1985
# extracting: WhitePond.Krause.2019
# extracting: LS009.Ledu.2010
# extracting: MD99-2266.Moossen.2015
# extracting: Mackenzie.Woltering.2014
# extracting: Reiarsdalvatnet.Seppa.2009
# extracting: ESM-1.Mackay.2012
# extracting: andy.Szeicz.1995
# extracting: MD95-2011.Calvo.2002
# extracting: Tourbiere_deLanorie_CoteauJaune.Comtois.1982
# extracting: NorthGRIP.Gkinis.2014
# extracting: hjort.Schmidt.2011
# extracting: MD952043
# extracting: Eldora.Maher.1969
# extracting: Buckbean.Baker.1976
# extracting: Turkana.Berke.2012
# extracting: Sellevollmyra.Vorren.2007
# extracting: SchellingsBog.Barron.2004
# extracting: MD99-2256.Jennings.2015
# extracting: Pixie.Brown.2002
# extracting: Leviathan.Lachniet.2014
# extracting: FiddlersPond.White.1982
# extracting: GISP2.Kobashi.2012
# extracting: Boone.White.1986
# extracting: LoneFoxLake.MacDonald.1985
# extracting: Minnie.McAndrews.1992
# extracting: OroLake.Michels.2007
# extracting: A7.Sun.2005
# extracting: 74KL_TEX86.Huguet.2006
# extracting: Cub.Rasmussen.1982
# extracting: bjornfjelltjorn.Brooks.2006
# extracting: TTR17_434G.Rodrigo-Gamiz.2014
# extracting: Stomyren..2008
# extracting: Korallgrottan.Sundqvist.2010
# extracting: BlueMoundsCreek.Davis.1977
# extracting: Lyadhej-To.Pollen.Russia
# extracting: GeoB3910.Jaeschke.2007
# extracting: svartvatnet.Seppa.2009
# extracting: SO42_74KL
# extracting: Crowfoot.Reasoner.1996
# extracting: LakeGB1.Gajewski.1991
# extracting: Cranberry.McAndrews.NA
# extracting: MD99-2256..2010
# extracting: VuolepNjakajaure.Heinrichs.2006
# extracting: LittlePond.Marsicek.2013
# extracting: GeoB12610-2.Rippert.2015
# extracting: Aus-KempWimmeraLakes
# extracting: MD01-2444.Martrat.2007
# extracting: akvaqiak.Frechette.2009
# extracting: GreyIslands.Cullen.2002
# extracting: Vouskku.Larocque.2004
# extracting: ClearPond_SCarolina.Hussey.1993
# extracting: Station803.Bringue.2012
# extracting: RiviereFeuilles2.Larouche.1981
# extracting: HeshangCave.Hu.2007
# extracting: Castor.Larouche.NA
# extracting: ElJunco.Conroy.2008
# extracting: Two-YourtsLake.Nazarova.2013
# extracting: Holzmaar.Pollen-Germany-Holzmaar.Kuehl
# extracting: Midden.Cluster7.2019
# extracting: Midden.Cluster6.2019
# extracting: RR1313_23PC
# extracting: honeymoon.Cwynar.1991
# extracting: MD97_2120
# extracting: JR01.Zabenskie.2007
# extracting: Sutherland.Shuman.2016
# extracting: Faelen.Wirth.2013
# extracting: Temje.Nazarova.2013
# extracting: Aden.Tierney.2013
# extracting: Queens.MacDonald.1990
# extracting: GISP2.Kobashi.2017
# extracting: hail.Cwynar.1995
# extracting: GunNuur.Chen.2008
# extracting: Crooked.Engels.2012
# extracting: LakeMina.Pollen.USA
# extracting: Eleanor.Gavin.2011
# extracting: NA87_22
# extracting: D13902
# extracting: MD95-2015.Giraudeau.2002
# extracting: IndianPrairieFen.Whitlock.1995
# extracting: Juyanze.Chen.2008
# extracting: Gemini.Samartin.2017
# extracting: NGRIP..2004
# extracting: LakeOfTheWoods.Pribyl.2014
# extracting: Marcella.Anderson.2007
# extracting: GeoB77023.Castaeda.2010
# extracting: NikolayLake.Andreev.2004
# extracting: GeoB7926_2
# extracting: Demont.Kapp.NA
# extracting: ODP1017E.Kennett.2000
# extracting: BoundaryLake.Stravers.1981
# extracting: Copley.Fall.1997
# extracting: HangingLake.Kurek.2009
# extracting: greyling.Mckay.2009
# extracting: Okoboji.Shuman.2016
# extracting: LagunaDeAljojuca.Bhattacharya.2015
# extracting: Vatnamyri.Caseldine.2006
# extracting: Dye3.Vinther.2006
# extracting: MR003-K03-PC01.Harada.2004
# extracting: TY93-905.Kim.2004
# extracting: Seukokjaure.Rosen.2003
# extracting: Wulun.Chen.2008
# extracting: TsoMoriri.Leipe.2013
# extracting: SS1381.Anderson.2012
# extracting: 3MPond.Pellatt.2000
# extracting: Keele.Szeicz.1995
# extracting: Chippewa.Bailey.1981
# extracting: Redondo.Brubaker.1983
# extracting: Bosumtwi.Shanahan.2015
# extracting: LiangLuarCave.Griggiths.2009
# extracting: ForestPond2.Lynch.1998
# extracting: MaraisdeKeswick.Larouche.1986
# extracting: GeoB10069_3
# extracting: Qinghai.Leipe.2013
# extracting: HighLake.Shuman.2016
# extracting: Grimsel.Wirth.2013
# extracting: LakeQinghai.Hou.2016
# extracting: Nedlouc.Larouche.1981
# extracting: liltlvatn.Seppa.2009
# extracting: Radtke.Webb.1983
# extracting: ARC5.Belt.2010
# extracting: TiancaiLake.Zhang.2017
# extracting: ODP_1240
# extracting: ParadiseLake.Steinman.2016
# extracting: TALDICE.Mezgec.2017
# extracting: EastBalticBog.Anderson.1980
# extracting: LagoDellAccesa.Finsinger.2010
# extracting: V1928
# extracting: BayanNuur.Chen.2008
# extracting: SO189-119KL.Mohtadi.2014
# extracting: LR01.Gajewski.1993
# extracting: Komosomolskaia.Ciais.1992
# extracting: Malangen.Husum.2004
# extracting: M44-KL71.Sperling.2003
# extracting: LacPatricia.McAndrews.1983
# extracting: Redrock.Maher.1972
# extracting: GeoB33131.Lamy.2002
# extracting: IOW225517.Elmis.2003
# extracting: PyramidLake.Benson.2001
# extracting: naujg1.Willemse.1999
# extracting: MD972141
# extracting: WAISDivide.Cuffey.2016
# extracting: north.Axford.2013
# extracting: LacHamard.Stravers.1981
# extracting: Axe.McAndrews.No
# extracting: EagleLake.Rosenberg.2004
# extracting: BoundaryPond.Mott.1977
# extracting: GeoB1711_4
# extracting: LifebuoyLake.Solivieva.2015
# extracting: Rapid.Fall.1994
# extracting: PogoniaBog.Cushing.1979
# extracting: MV0811-14JC.Du.2018
# extracting: MD02_2594
# extracting: PetenItza.Curtis.1998
# extracting: Dolgoe.Wolfe.2000
# extracting: DevilsLake.Shuman.2016
# extracting: GeoB9528-3.Collins.2013
# extracting: MD95_2011
# extracting: GeoB12615_4
# extracting: LagunaChaplin.Pollen.Bolivia
# extracting: M77_2_056_5
# Created time series: 6396 entries
# CPU times: user 7.49 s, sys: 1.57 s, total: 9.07 s
# Wall time: 9.03 s

# %% [markdown]
# Extract only the temperature series with units in degrees Celsius

# %%
filtered_ts_temp12k = lipd.filterTs(all_series,'paleoData_inCompilation == Temp12k')
filtered_ts_useinglobal = lipd.filterTs(filtered_ts_temp12k,'paleoData_useInGlobalTemperatureAnalysis == TRUE')
temperatures = lipd.filterTs(filtered_ts_useinglobal,'paleoData_units == degC')
sorted(temperatures[0])
# Out:
# Found 1085 matches from 6396 columns
# Found 548 matches from 1085 columns
# Found 509 matches from 548 columns
# ['@context',
#  'age',
#  'ageUnits',
#  'agesPerKyr',
#  'archiveType',
#  'archiveTypeOriginal',
#  'createdBy',
#  'dataSetName',
#  'depth',
#  'depthUnits',
#  'geo_countryOcean',
#  'geo_location',
#  'geo_meanElev',
#  'geo_meanLat',
#  'geo_meanLon',
#  'geo_notes',
#  'geo_siteName',
#  'investigator',
#  'lastUpdated',
#  'lipdVersion',
#  'lipdverseLink',
#  'maxYear',
#  'minYear',
#  'mode',
#  'nUniqueAges',
#  'neotomaCoreID',
#  'paleoData_QCCertification',
#  'paleoData_QCLastUpdated',
#  'paleoData_TSid',
#  'paleoData_calibration_method',
#  'paleoData_calibration_methodDetail',
#  'paleoData_calibration_uncertainty',
#  'paleoData_calibration_uncertaintyType',
#  'paleoData_datum',
#  'paleoData_filename',
#  'paleoData_hasMaxValue',
#  'paleoData_hasMeanValue',
#  'paleoData_hasMedianValue',
#  'paleoData_hasMinValue',
#  'paleoData_hasResolution_hasMaxValue',
#  'paleoData_hasResolution_hasMeanValue',
#  'paleoData_hasResolution_hasMedianValue',
#  'paleoData_hasResolution_hasMinValue',
#  'paleoData_inCompilation',
#  'paleoData_interpretation',
#  'paleoData_meanValue12k',
#  'paleoData_medianRes12k',
#  'paleoData_missingValue',
#  'paleoData_number',
#  'paleoData_proxy',
#  'paleoData_proxyDetail',
#  'paleoData_proxyGeneral',
#  'paleoData_proxyLumps',
#  'paleoData_proxyOriginal',
#  'paleoData_tableName',
#  'paleoData_temp12kDkIndex',
#  'paleoData_units',
#  'paleoData_unitsOriginal',
#  'paleoData_useInGlobalTemperatureAnalysis',
#  'paleoData_values',
#  'paleoData_variableName',
#  'paleoData_variableNameOriginal',
#  'pub1_citation',
#  'pub1_doi',
#  'pub1_pubDataUrl',
#  'pub2_citation',
#  'pub2_doi',
#  'pub2_pubDataUrl',
#  'tableType',
#  'time_id']

# %% [markdown]
# <a id='meta_cols'></a>Transform the temperatures into pandas series. The `meta_cols` is the meta data that should be available as column in the data frame and has to match one of the keys in the previous list. The `meta_names` then specifies how the corresponding field from `meta_cols` appears in the final data frame.

# %%
meta_cols = ['geo_meanLon', 'geo_meanLat', 'dataSetName', 'paleoData_variableName']
meta_names = ['lon', 'lat', 'dataSetName', 'variableName']

series = [
    pd.Series(
        np.asarray(d['paleoData_values'], dtype=float),
        index=np.asarray(d['age'], dtype=float),
        name=tuple(d.get(name, np.nan) for name in meta_cols))
    for d in temperatures if 'age' in d]

# %% [markdown]
# and bin them based on centennial scales and merge them into one single dataframe

# %%
def age_grouper(age):
    """Bin age to centuries"""
    return age - (age % binwidth)

# %%
binned = [s.groupby(age_grouper).mean() for s in series]

merged = binned[0].to_frame()
merged.columns.names = meta_names

for s in binned[1:]:
    merged = merged.merge(s.to_frame(), left_index=True, right_index=True,
                          how='outer')
    
merged = merged.T

# %% [markdown]
# Now save the results

# %%
merged.to_csv('../data/binned-temperature-data.tsv', '\t')

# %% [markdown]
# <a id='final'></a>That's it! If the notebook has finished, you can download the temperature data [here](../data/binned-temperature-data.tsv) and the corresponding meta data [here](../data/meta.tsv) as tab-separated files.
#
# So let's have a look into the final temperature data:

# %%
merged
# Out:
#                                                          -300.0      \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature          NaN
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature          NaN
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature          NaN
#  17.3380  -34.7100 MD02_2594               temperature          NaN
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature          NaN
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                          -200.0      \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature          NaN
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature          NaN
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature          NaN
#  17.3380  -34.7100 MD02_2594               temperature          NaN
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature          NaN
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                          -100.0      \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature        8.015
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature          NaN
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature        7.100
#  17.3380  -34.7100 MD02_2594               temperature          NaN
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature          NaN
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                           0.0        \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature     8.005000
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature     9.618000
# -38.5000   72.6000 Alley.GISP2.2000        temperature   -37.785174
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature     7.046667
#  17.3380  -34.7100 MD02_2594               temperature    15.716000
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature    15.191000
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                           100.0      \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature     7.798000
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature          NaN
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature     7.117333
#  17.3380  -34.7100 MD02_2594               temperature          NaN
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature          NaN
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                           200.0      \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature          NaN
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature          NaN
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature       25.300
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature        7.047
#  17.3380  -34.7100 MD02_2594               temperature          NaN
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature       15.197
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                           300.0      \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature       8.5950
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature      10.4890
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature       7.0095
#  17.3380  -34.7100 MD02_2594               temperature      15.1730
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature          NaN
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                           400.0      \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature          NaN
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature       8.5890
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature       6.9615
#  17.3380  -34.7100 MD02_2594               temperature          NaN
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature          NaN
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                           500.0      \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature       8.8490
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature       7.5665
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature          NaN
#  17.3380  -34.7100 MD02_2594               temperature          NaN
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature          NaN
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                           600.0      ...  \
# lon       lat      dataSetName             variableName              ...
# -80.4100   43.2400 Hams.Bennett.1987       temperature        8.500  ...
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature        7.509  ...
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN  ...
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN  ...
#  37.3800  -18.5650 GeoB9307_3              temperature       25.900  ...
# ...                                                             ...  ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature        7.599  ...
#  17.3380  -34.7100 MD02_2594               temperature          NaN  ...
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature       14.998  ...
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN  ...
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN  ...
#
#                                                           1237500.0  \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature          NaN
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature          NaN
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature          NaN
#  17.3380  -34.7100 MD02_2594               temperature          NaN
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature          NaN
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                           1240500.0  \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature          NaN
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature          NaN
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature          NaN
#  17.3380  -34.7100 MD02_2594               temperature          NaN
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature          NaN
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                           1241800.0  \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature          NaN
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature          NaN
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature          NaN
#  17.3380  -34.7100 MD02_2594               temperature          NaN
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature          NaN
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                           1243100.0  \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature          NaN
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature          NaN
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature          NaN
#  17.3380  -34.7100 MD02_2594               temperature          NaN
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature          NaN
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                           1261400.0  \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature          NaN
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature          NaN
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature          NaN
#  17.3380  -34.7100 MD02_2594               temperature          NaN
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature          NaN
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                           1263300.0  \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature          NaN
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature          NaN
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature          NaN
#  17.3380  -34.7100 MD02_2594               temperature          NaN
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature          NaN
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                           1264800.0  \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature          NaN
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature          NaN
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature          NaN
#  17.3380  -34.7100 MD02_2594               temperature          NaN
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature          NaN
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                           1266200.0  \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature          NaN
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature          NaN
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature          NaN
#  17.3380  -34.7100 MD02_2594               temperature          NaN
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature          NaN
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                           1267900.0  \
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature          NaN
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature          NaN
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature          NaN
#  17.3380  -34.7100 MD02_2594               temperature          NaN
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature          NaN
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
#                                                           1277300.0
# lon       lat      dataSetName             variableName
# -80.4100   43.2400 Hams.Bennett.1987       temperature          NaN
#  146.5914 -42.6799 EagleTarn.Rees.2010     temperature          NaN
# -38.5000   72.6000 Alley.GISP2.2000        temperature          NaN
#  33.1983  -1.2317  Victoria.Berke.2012     temperature          NaN
#  37.3800  -18.5650 GeoB9307_3              temperature          NaN
# ...                                                             ...
# -93.6300   45.0400 PogoniaBog.Cushing.1979 temperature          NaN
#  17.3380  -34.7100 MD02_2594               temperature          NaN
#  127.0700  71.8700 Dolgoe.Wolfe.2000       temperature          NaN
#  39.8408  -7.1383  GeoB12615_4             temperature          NaN
# -81.1247  -3.7498  M77_2_056_5             temperature          NaN
#
# [504 rows x 2724 columns]

# %%
merged.loc[merged.iloc[:, 0].notnull()]
# Out:
#                                                   -300.0      -200.0      \
# lon     lat   dataSetName           variableName
# -120.82 49.54 BCTempComp.Gavin.2013 temperature      -0.6715     -0.5005
# -105.54 40.08 Redrock.Maher.1972    temperature       2.2950         NaN
#
#                                                   -100.0       0.0        \
# lon     lat   dataSetName           variableName
# -120.82 49.54 BCTempComp.Gavin.2013 temperature          NaN   -1.126667
# -105.54 40.08 Redrock.Maher.1972    temperature        1.665         NaN
#
#                                                    100.0       200.0      \
# lon     lat   dataSetName           variableName
# -120.82 49.54 BCTempComp.Gavin.2013 temperature       -0.414      0.6675
# -105.54 40.08 Redrock.Maher.1972    temperature        2.173         NaN
#
#                                                    300.0       400.0      \
# lon     lat   dataSetName           variableName
# -120.82 49.54 BCTempComp.Gavin.2013 temperature         0.28      0.3125
# -105.54 40.08 Redrock.Maher.1972    temperature          NaN      2.1020
#
#                                                    500.0       600.0      ...  \
# lon     lat   dataSetName           variableName                          ...
# -120.82 49.54 BCTempComp.Gavin.2013 temperature      -0.4055         NaN  ...
# -105.54 40.08 Redrock.Maher.1972    temperature          NaN       2.739  ...
#
#                                                    1237500.0   1240500.0  \
# lon     lat   dataSetName           variableName
# -120.82 49.54 BCTempComp.Gavin.2013 temperature          NaN         NaN
# -105.54 40.08 Redrock.Maher.1972    temperature          NaN         NaN
#
#                                                    1241800.0   1243100.0  \
# lon     lat   dataSetName           variableName
# -120.82 49.54 BCTempComp.Gavin.2013 temperature          NaN         NaN
# -105.54 40.08 Redrock.Maher.1972    temperature          NaN         NaN
#
#                                                    1261400.0   1263300.0  \
# lon     lat   dataSetName           variableName
# -120.82 49.54 BCTempComp.Gavin.2013 temperature          NaN         NaN
# -105.54 40.08 Redrock.Maher.1972    temperature          NaN         NaN
#
#                                                    1264800.0   1266200.0  \
# lon     lat   dataSetName           variableName
# -120.82 49.54 BCTempComp.Gavin.2013 temperature          NaN         NaN
# -105.54 40.08 Redrock.Maher.1972    temperature          NaN         NaN
#
#                                                    1267900.0   1277300.0
# lon     lat   dataSetName           variableName
# -120.82 49.54 BCTempComp.Gavin.2013 temperature          NaN         NaN
# -105.54 40.08 Redrock.Maher.1972    temperature          NaN         NaN
#
# [2 rows x 2724 columns]
